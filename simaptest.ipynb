# %%
import requests
import json
from dotenv import load_dotenv
import os
from openai import OpenAI

# --- Simap API Konfiguration ---
SIMAP_BASE_URL = "https://simap.ch" # WICHTIG: Korrekte Basis-URL hier eintragen!
SIMAP_SEARCH_ENDPOINT = "/api/publications/v2/project/project-search"
SIMAP_DETAIL_ENDPOINT_TEMPLATE = "/api/publications/v1/project/{projectId}/publication-details/{publicationId}"


load_dotenv(override=True)

webhook_url = os.environ["SLACK_WEBHOOK_BIDBOT"]

client = OpenAI(
    # This is the default and can be omitted
    api_key= os.environ["OPENAI_API_KEY"]
)

# %%
def call_simap_api(endpoint_url, params=None):
    """Ruft einen Simap API Endpunkt auf und gibt die JSON-Antwort zurück."""
    try:
        print(f"INFO: Rufe Simap API auf: {endpoint_url} mit Parametern: {params}")
        # Da Sie sagten, keine Authentifizierung nötig:
        response = requests.get(endpoint_url, params=params)
        response.raise_for_status()  # Löst einen Fehler aus bei HTTP-Fehlercodes 4xx/5xx
        return response.json()
    except requests.exceptions.HTTPError as http_err:
        print(f"FEHLER: HTTP-Fehler beim Aufruf der Simap API ({endpoint_url}): {http_err}")
        print(f"FEHLER: Antwort-Text: {response.text if response else 'Keine Antwort'}")
    except requests.exceptions.RequestException as e:
        print(f"FEHLER: Allgemeiner Fehler beim Aufruf der Simap API ({endpoint_url}): {e}")
    except json.JSONDecodeError as e:
        print(f"FEHLER: Antwort der Simap API ({endpoint_url}) ist kein valides JSON: {e}")
        print(f"FEHLER: Antwort-Text: {response.text if response else 'Keine Antwort'}")
    return None

# %%
print("--- Schritt 1: Alle relevanten Projektseiten abrufen (mit Paginierung) ---")
search_url = SIMAP_BASE_URL + SIMAP_SEARCH_ENDPOINT

# Ihre gewünschten initialen Query-Parameter
# WICHTIG: Prüfen Sie in der Simap Swagger-UI, ob es einen Parameter gibt,
# um direkt nach pubType zu filtern, z.B. pubTypes="tender,advance_notice"
# Wenn ja, fügen Sie ihn hier hinzu!
initial_query_params = {
    "lang": "de",
    "processTypes": "open",
    "cpvCodes": ["72000000","48000000"], 
    "newestPublicationFrom": "2025-05-27"
    # "pubTypes": "tender,advance_notice" # Beispiel, falls der Parameter existiert
}

all_fetched_projects = []
current_last_item = None
page_count = 0
max_pages_to_fetch = 100 # Sicherheitslimit, um Endlosschleifen zu vermeiden (anpassen!)

print(f"INFO: Starte Abruf von Projektliste mit initialen Parametern: {initial_query_params}")

while True:
    page_count += 1
    print(f"INFO: Rufe Seite {page_count} ab...")
    
    current_query_params = initial_query_params.copy()
    if current_last_item:
        # WICHTIG: Ersetzen Sie 'lastItemCursor' durch den tatsächlichen Query-Parameter-Namen,
        # den die Simap-API für die Paginierung mit dem 'lastItem'-Wert erwartet!
        # Übliche Namen könnten sein: 'lastItem', 'pageCursor', 'startAfter', 'offsetToken' etc.
        # Schauen Sie in der Simap API Dokumentation (Swagger) nach!
        current_query_params["lastItem"] = current_last_item # Annahme des Parameternamens

    page_data = call_simap_api(search_url, params=current_query_params)

    if page_data and "projects" in page_data:
        projects_on_page = page_data["projects"]
        print(f"INFO: {len(projects_on_page)} Projekte auf dieser Seite gefunden.")
        all_fetched_projects.extend(projects_on_page)

        pagination_info = page_data.get("pagination")
        if pagination_info:
            print(f"INFO: Pagination Info: {pagination_info}")
            items_per_page = pagination_info.get("itemsPerPage", 20) # Standardwert falls nicht vorhanden
            # Bedingung zum Stoppen: Wenn weniger Projekte als 'itemsPerPage' geliefert wurden
            # ODER wenn 'lastItem' nicht mehr vorhanden/null ist (sicherere Methode, falls 'lastItem' immer kommt)
            if "lastItem" in pagination_info and pagination_info["lastItem"]:
                current_last_item = pagination_info["lastItem"]
                if len(projects_on_page) < items_per_page: # Wenn letzte Seite erreicht
                    print("INFO: Weniger Projekte als 'itemsPerPage' erhalten, wahrscheinlich letzte Seite.")
                    break
            else: # Kein 'lastItem' mehr in pagination oder 'lastItem' ist null
                print("INFO: Kein 'lastItem' mehr in Pagination Info oder 'lastItem' ist null. Stoppe Paginierung.")
                break
        else: # Keine Pagination-Info mehr
            print("INFO: Keine Pagination-Informationen mehr in der Antwort. Stoppe Paginierung.")
            break
        
        if page_count >= max_pages_to_fetch:
            print(f"WARNUNG: Maximal Anzahl von {max_pages_to_fetch} Seiten abgerufen. Stoppe Paginierung, um Endlosschleife zu vermeiden.")
            break
            
    else:
        print(f"FEHLER: Keine Projekte auf Seite {page_count} gefunden oder Fehler beim Abrufen. Stoppe Paginierung.")
        if page_data:
             print(f"Antwort von Simap (Seite {page_count}): {page_data}")
        break

print(f"\nINFO: Insgesamt {len(all_fetched_projects)} Projekte über {page_count} Seite(n) abgerufen.")

# Client-seitige Filterung nach pubType, falls nicht API-seitig möglich
projects_for_application = []
if all_fetched_projects:
    for project in all_fetched_projects:
        pub_type = project.get("pubType", "").lower()
        if pub_type in ["tender", "advance_notice"]:
            projects_for_application.append(project)



print(f"INFO: {len(projects_for_application)} Projekte sind 'tender' oder 'advance_notice' und werden weiter analysiert.")
# Out:
# --- Schritt 1: Alle relevanten Projektseiten abrufen (mit Paginierung) ---
# INFO: Starte Abruf von Projektliste mit initialen Parametern: {'lang': 'de', 'processTypes': 'open', 'cpvCodes': ['72000000', '48000000'], 'newestPublicationFrom': '2025-05-27'}
# INFO: Rufe Seite 1 ab...
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v2/project/project-search mit Parametern: {'lang': 'de', 'processTypes': 'open', 'cpvCodes': ['72000000', '48000000'], 'newestPublicationFrom': '2025-05-27'}
# INFO: 20 Projekte auf dieser Seite gefunden.
# INFO: Pagination Info: {'lastItem': '20250527|16842', 'itemsPerPage': 20}
# INFO: Rufe Seite 2 ab...
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v2/project/project-search mit Parametern: {'lang': 'de', 'processTypes': 'open', 'cpvCodes': ['72000000', '48000000'], 'newestPublicationFrom': '2025-05-27', 'lastItem': '20250527|16842'}
# INFO: 3 Projekte auf dieser Seite gefunden.
# INFO: Pagination Info: {'lastItem': '20250527|17552', 'itemsPerPage': 20}
# INFO: Weniger Projekte als 'itemsPerPage' erhalten, wahrscheinlich letzte Seite.
#
# INFO: Insgesamt 23 Projekte über 2 Seite(n) abgerufen.
# INFO: 10 Projekte sind 'tender' oder 'advance_notice' und werden weiter analysiert.

# %%
import time # Für Pausen zwischen API-Aufrufen

print("\n--- Abruf der Detailinformationen für die gefilterten Projekte ---")

# Diese Liste wird die abgerufenen Detail-JSON-Objekte speichern
fetched_project_details_list = []
# Diese Liste kann Fehlerinformationen speichern, falls ein Detailabruf fehlschlägt
detail_fetch_errors = []

if 'projects_for_application' in locals() and projects_for_application:
    # Für den Testlauf können Sie die Anzahl der zu verarbeitenden Projekte begrenzen:
    # projects_to_get_details_for = projects_for_application[:2] # Z.B. nur die ersten 2
    projects_to_get_details_for = projects_for_application # Alle Projekte aus der gefilterten Liste verarbeiten
    
    print(f"INFO: Beginne mit dem Abruf von Detailinformationen für {len(projects_to_get_details_for)} Projekte.")

    for index, project_summary in enumerate(projects_to_get_details_for):
        project_id_for_detail = project_summary.get("id")
        publication_id_for_detail = project_summary.get("publicationId")
        project_title_summary = project_summary.get('title', {}).get('de', 'Unbekannter Titel')

        print(f"\n[{index + 1}/{len(projects_to_get_details_for)}] Verarbeite Projekt: '{project_title_summary}'")
        print(f"  Summary Projekt ID: {project_id_for_detail}")
        print(f"  Summary Publikations ID: {publication_id_for_detail}")

        if not project_id_for_detail or not publication_id_for_detail:
            error_message = f"FEHLER: Fehlende Projekt-ID ('{project_id_for_detail}') oder Publikations-ID ('{publication_id_for_detail}') im Summary. Überspringe Detailabruf."
            print(error_message)
            detail_fetch_errors.append({
                "summary_project_id": project_id_for_detail,
                "summary_publication_id": publication_id_for_detail,
                "summary_title": project_title_summary,
                "error": error_message
            })
            continue

        # URL für den Detail-API-Aufruf zusammenbauen
        detail_url = SIMAP_BASE_URL + SIMAP_DETAIL_ENDPOINT_TEMPLATE.format(
            projectId=project_id_for_detail, 
            publicationId=publication_id_for_detail
        )
        
        # Detail-API aufrufen
        project_details_json = call_simap_api(detail_url)

        if project_details_json:
            print(f"INFO: Details für Projekt '{project_title_summary}' (Pub-ID: {publication_id_for_detail}) erfolgreich abgerufen.")
            fetched_project_details_list.append(project_details_json)
            
            # Optional: Einen kleinen Teil der abgerufenen Details anzeigen
            # print("  Ausschnitt der Details:")
            # print(f"    Detail-Titel (DE): {project_details_json.get('project-info', {}).get('title', {}).get('de', 'N/A')}")
            # desc_snippet = project_details_json.get('procurement', {}).get('orderDescription', {}).get('de', 'N/A')
            # print(f"    Detail-Beschreibung (DE-Anfang): {desc_snippet[:100] if desc_snippet else 'N/A'}...")
        else:
            error_message = f"FEHLER: Konnte keine Details für Projekt '{project_title_summary}' (Pub-ID: {publication_id_for_detail}) abrufen."
            print(error_message)
            detail_fetch_errors.append({
                "summary_project_id": project_id_for_detail,
                "summary_publication_id": publication_id_for_detail,
                "summary_title": project_title_summary,
                "detail_url_called": detail_url,
                "error": error_message
            })
            
        # Eine höfliche Pause zwischen den API-Aufrufen einlegen
        print("INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...")
        time.sleep(1) # Warte 1 Sekunde

    print(f"\n--- Detailabruf abgeschlossen ---")
    print(f"INFO: Erfolgreich Details für {len(fetched_project_details_list)} von {len(projects_to_get_details_for)} Projekten abgerufen.")
    if detail_fetch_errors:
        print(f"WARNUNG: Bei {len(detail_fetch_errors)} Projekten gab es Fehler beim Detailabruf.")
        # print("Fehlerdetails:", json.dumps(detail_fetch_errors, indent=2, ensure_ascii=False))


    # Ausgabe der ersten paar abgerufenen Projektdetails zur Überprüfung
    if fetched_project_details_list:
        print("\n--- Erste(s) abgerufene(s) Projektdetail(s) zur Ansicht (max. 1) ---")
        # Wir geben die Struktur des ersten Elements aus, um zu sehen, ob es passt
        print(json.dumps(fetched_project_details_list[0], indent=2, ensure_ascii=False, default=str))
    else:
        print("INFO: Keine Projektdetails erfolgreich abgerufen.")

else:
    print("FEHLER: Die Liste 'projects_for_application' wurde in der vorherigen Zelle nicht erfolgreich erstellt oder ist leer.")
    print("Bitte führen Sie zuerst die Zelle zur Projektabfrage und -filterung (Zelle 4) erfolgreich aus.")

# Die Variable 'fetched_project_details_list' enthält nun die Detail-JSON-Objekte
# der Projekte, für die der Abruf erfolgreich war.
# Diese können Sie im nächsten Schritt für die OpenAI-Bewertung verwenden oder weiter analysieren.
# Out:
# --- Abruf der Detailinformationen für die gefilterten Projekte ---
# INFO: Beginne mit dem Abruf von Detailinformationen für 87 Projekte.
#
# [1/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 0712ca2c-7429-4f83-ac51-903b7358bc0f
#   Summary Publikations ID: 4b400201-3a77-4daa-8de3-faf003175cdb
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/0712ca2c-7429-4f83-ac51-903b7358bc0f/publication-details/4b400201-3a77-4daa-8de3-faf003175cdb mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 4b400201-3a77-4daa-8de3-faf003175cdb) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [2/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 7fafbf92-d6d7-4577-af41-0a5258d71215
#   Summary Publikations ID: 43b44738-281a-4a55-90c4-c1307de76dd5
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/7fafbf92-d6d7-4577-af41-0a5258d71215/publication-details/43b44738-281a-4a55-90c4-c1307de76dd5 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 43b44738-281a-4a55-90c4-c1307de76dd5) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [3/87] Verarbeite Projekt: 'Bedienung und Instandhaltung Baudienstwagen (Xans74, WTW, Silad)'
#   Summary Projekt ID: 1689b278-f9e9-4412-9f86-b743dcf80954
#   Summary Publikations ID: 398bc72c-3bdf-42a4-bcc7-32c9a684f6c8
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/1689b278-f9e9-4412-9f86-b743dcf80954/publication-details/398bc72c-3bdf-42a4-bcc7-32c9a684f6c8 mit Parametern: None
# INFO: Details für Projekt 'Bedienung und Instandhaltung Baudienstwagen (Xans74, WTW, Silad)' (Pub-ID: 398bc72c-3bdf-42a4-bcc7-32c9a684f6c8) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [4/87] Verarbeite Projekt: 'Datenaustauschplattform DAP'
#   Summary Projekt ID: 44ba2363-15fb-41dd-806d-fea7b73a3b62
#   Summary Publikations ID: 75d850bc-6235-45e3-88a4-604e24f425e3
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/44ba2363-15fb-41dd-806d-fea7b73a3b62/publication-details/75d850bc-6235-45e3-88a4-604e24f425e3 mit Parametern: None
# INFO: Details für Projekt 'Datenaustauschplattform DAP' (Pub-ID: 75d850bc-6235-45e3-88a4-604e24f425e3) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [5/87] Verarbeite Projekt: 'IWB, Nachumhüllungen von Stahlrohrleitungen'
#   Summary Projekt ID: 8711c1b7-86e4-430c-9316-4f09275c1132
#   Summary Publikations ID: c02a65a5-fae3-4152-871e-b1e1637ca656
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/8711c1b7-86e4-430c-9316-4f09275c1132/publication-details/c02a65a5-fae3-4152-871e-b1e1637ca656 mit Parametern: None
# INFO: Details für Projekt 'IWB, Nachumhüllungen von Stahlrohrleitungen' (Pub-ID: c02a65a5-fae3-4152-871e-b1e1637ca656) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [6/87] Verarbeite Projekt: 'Instandhaltung (Wartung und Unterhalt) Polycom Regionalnetz Kanton Glarus'
#   Summary Projekt ID: 538bed70-311e-4283-8085-c2108bb8eb20
#   Summary Publikations ID: 857b73b7-2c3c-4a18-8aa4-cc6e0dd8a90f
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/538bed70-311e-4283-8085-c2108bb8eb20/publication-details/857b73b7-2c3c-4a18-8aa4-cc6e0dd8a90f mit Parametern: None
# INFO: Details für Projekt 'Instandhaltung (Wartung und Unterhalt) Polycom Regionalnetz Kanton Glarus' (Pub-ID: 857b73b7-2c3c-4a18-8aa4-cc6e0dd8a90f) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [7/87] Verarbeite Projekt: 'Anlagenverkabelung (NS) Bundle 2025-1'
#   Summary Projekt ID: 2a6573d4-0985-451e-8ea0-9a8437e1624a
#   Summary Publikations ID: d5552872-4ba6-4a16-95dd-9ec2092e9dca
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/2a6573d4-0985-451e-8ea0-9a8437e1624a/publication-details/d5552872-4ba6-4a16-95dd-9ec2092e9dca mit Parametern: None
# INFO: Details für Projekt 'Anlagenverkabelung (NS) Bundle 2025-1' (Pub-ID: d5552872-4ba6-4a16-95dd-9ec2092e9dca) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [8/87] Verarbeite Projekt: '40MVA und 16MVA NE4-Transformatoren'
#   Summary Projekt ID: 4679216d-edc5-492b-964f-61bdb03c8b77
#   Summary Publikations ID: a71aac1e-8943-4932-b9b3-9f25a5f4846a
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/4679216d-edc5-492b-964f-61bdb03c8b77/publication-details/a71aac1e-8943-4932-b9b3-9f25a5f4846a mit Parametern: None
# INFO: Details für Projekt '40MVA und 16MVA NE4-Transformatoren' (Pub-ID: a71aac1e-8943-4932-b9b3-9f25a5f4846a) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [9/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: cf50e1a2-50cc-41df-9195-321981832f41
#   Summary Publikations ID: a0fca92f-a6e4-446e-b70f-0be4b6477234
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/cf50e1a2-50cc-41df-9195-321981832f41/publication-details/a0fca92f-a6e4-446e-b70f-0be4b6477234 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: a0fca92f-a6e4-446e-b70f-0be4b6477234) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [10/87] Verarbeite Projekt: 'Kommunalfahrzeug, Ersatzbeschaffung'
#   Summary Projekt ID: 52539aa3-2c52-4140-a10f-afd6182022ea
#   Summary Publikations ID: ebf47f21-bf10-4d09-9637-2c804d597fd3
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/52539aa3-2c52-4140-a10f-afd6182022ea/publication-details/ebf47f21-bf10-4d09-9637-2c804d597fd3 mit Parametern: None
# INFO: Details für Projekt 'Kommunalfahrzeug, Ersatzbeschaffung' (Pub-ID: ebf47f21-bf10-4d09-9637-2c804d597fd3) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [11/87] Verarbeite Projekt: 'Stadt Arbon, Sanierung St. Gallerstrasse'
#   Summary Projekt ID: 5dbb1097-b666-432d-a41c-fc8d3d1d9518
#   Summary Publikations ID: 526ec0c4-ca11-478c-acba-c62727c4168a
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/5dbb1097-b666-432d-a41c-fc8d3d1d9518/publication-details/526ec0c4-ca11-478c-acba-c62727c4168a mit Parametern: None
# INFO: Details für Projekt 'Stadt Arbon, Sanierung St. Gallerstrasse' (Pub-ID: 526ec0c4-ca11-478c-acba-c62727c4168a) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [12/87] Verarbeite Projekt: 'Lieferwagen Kanton Bern'
#   Summary Projekt ID: c4e28158-a589-45c7-ace4-4d2da3291388
#   Summary Publikations ID: 35a81641-762d-448e-a0c9-ae2106057602
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/c4e28158-a589-45c7-ace4-4d2da3291388/publication-details/35a81641-762d-448e-a0c9-ae2106057602 mit Parametern: None
# INFO: Details für Projekt 'Lieferwagen Kanton Bern' (Pub-ID: 35a81641-762d-448e-a0c9-ae2106057602) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [13/87] Verarbeite Projekt: 'IWB, Sekundärtechnik'
#   Summary Projekt ID: 5fd885d6-86e1-4c67-83a4-05f0a9ff6764
#   Summary Publikations ID: 21c33c27-4aa1-4f73-a12a-c565910a3712
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/5fd885d6-86e1-4c67-83a4-05f0a9ff6764/publication-details/21c33c27-4aa1-4f73-a12a-c565910a3712 mit Parametern: None
# INFO: Details für Projekt 'IWB, Sekundärtechnik' (Pub-ID: 21c33c27-4aa1-4f73-a12a-c565910a3712) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [14/87] Verarbeite Projekt: '(25132) 900 Geschäftsstelle Netzwerk FUTURE 2027 - 2034'
#   Summary Projekt ID: 257f0aff-1cfa-4182-92b8-82b38628cfec
#   Summary Publikations ID: 9b67e674-dc9c-4121-90e1-30ad9eb06ec0
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/257f0aff-1cfa-4182-92b8-82b38628cfec/publication-details/9b67e674-dc9c-4121-90e1-30ad9eb06ec0 mit Parametern: None
# INFO: Details für Projekt '(25132) 900 Geschäftsstelle Netzwerk FUTURE 2027 - 2034' (Pub-ID: 9b67e674-dc9c-4121-90e1-30ad9eb06ec0) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [15/87] Verarbeite Projekt: 'N09.62 MP-080292 - EP Sion Est - Sierre Est - Lot 125 - Guidage temporaire de trafic (ID 11220)'
#   Summary Projekt ID: 20ac3de7-5031-454e-945e-39d55d3bd5f0
#   Summary Publikations ID: add5a13b-3f26-4665-9f8a-580c5ba7a2d8
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/20ac3de7-5031-454e-945e-39d55d3bd5f0/publication-details/add5a13b-3f26-4665-9f8a-580c5ba7a2d8 mit Parametern: None
# INFO: Details für Projekt 'N09.62 MP-080292 - EP Sion Est - Sierre Est - Lot 125 - Guidage temporaire de trafic (ID 11220)' (Pub-ID: add5a13b-3f26-4665-9f8a-580c5ba7a2d8) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [16/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 65bf66d1-eebf-4333-82b6-309de3007b93
#   Summary Publikations ID: 1e1bf0cd-5e1e-4a19-b103-d0a75e4307fb
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/65bf66d1-eebf-4333-82b6-309de3007b93/publication-details/1e1bf0cd-5e1e-4a19-b103-d0a75e4307fb mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 1e1bf0cd-5e1e-4a19-b103-d0a75e4307fb) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [17/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 0b82d626-5d01-4868-9de0-dbc100086e6b
#   Summary Publikations ID: 6a4750bf-5b0e-4b02-aa21-a0f1a967f02a
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/0b82d626-5d01-4868-9de0-dbc100086e6b/publication-details/6a4750bf-5b0e-4b02-aa21-a0f1a967f02a mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 6a4750bf-5b0e-4b02-aa21-a0f1a967f02a) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [18/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: c805fc3c-7cd0-4161-a891-72a2e45db827
#   Summary Publikations ID: 16a050d3-0971-4b93-982b-209dfa096c6e
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/c805fc3c-7cd0-4161-a891-72a2e45db827/publication-details/16a050d3-0971-4b93-982b-209dfa096c6e mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 16a050d3-0971-4b93-982b-209dfa096c6e) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [19/87] Verarbeite Projekt: 'Hochwasserschutz Aare Bern, Instrumentierung Grundwassermonitoring, BKP 234 Elektrogeräte'
#   Summary Projekt ID: 0839aa39-94c6-4e42-aa71-e3e817420c54
#   Summary Publikations ID: 99c968c1-ee8b-4860-8ea0-f1df52d50e1d
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/0839aa39-94c6-4e42-aa71-e3e817420c54/publication-details/99c968c1-ee8b-4860-8ea0-f1df52d50e1d mit Parametern: None
# INFO: Details für Projekt 'Hochwasserschutz Aare Bern, Instrumentierung Grundwassermonitoring, BKP 234 Elektrogeräte' (Pub-ID: 99c968c1-ee8b-4860-8ea0-f1df52d50e1d) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [20/87] Verarbeite Projekt: 'Erneuerung des Supports und der Wartung der HR Access-Lösung von 2026 bis 2030'
#   Summary Projekt ID: 262ab6a8-40eb-439e-890e-f39aabddd508
#   Summary Publikations ID: 4f327976-68dc-4f38-9f1e-e2653a8742c4
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/262ab6a8-40eb-439e-890e-f39aabddd508/publication-details/4f327976-68dc-4f38-9f1e-e2653a8742c4 mit Parametern: None
# INFO: Details für Projekt 'Erneuerung des Supports und der Wartung der HR Access-Lösung von 2026 bis 2030' (Pub-ID: 4f327976-68dc-4f38-9f1e-e2653a8742c4) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [21/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 68e8d3f7-a712-4583-a841-0c547e4a3b32
#   Summary Publikations ID: eccfb449-f907-4c81-83f0-3d585ee98d58
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/68e8d3f7-a712-4583-a841-0c547e4a3b32/publication-details/eccfb449-f907-4c81-83f0-3d585ee98d58 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: eccfb449-f907-4c81-83f0-3d585ee98d58) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [22/87] Verarbeite Projekt: 'Wärme Laufenburg: Zubringerleitung Wärmeverbund II - Los 1 + 2 '
#   Summary Projekt ID: aeea5f92-99f7-4c0d-afd4-cfa35a081d95
#   Summary Publikations ID: 15539846-49cd-4218-8e82-c1e146234b86
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/aeea5f92-99f7-4c0d-afd4-cfa35a081d95/publication-details/15539846-49cd-4218-8e82-c1e146234b86 mit Parametern: None
# INFO: Details für Projekt 'Wärme Laufenburg: Zubringerleitung Wärmeverbund II - Los 1 + 2 ' (Pub-ID: 15539846-49cd-4218-8e82-c1e146234b86) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [23/87] Verarbeite Projekt: 'Muffen & Endverschlüsse BKW Energie AG'
#   Summary Projekt ID: a2f44a65-b500-4901-ab95-cb50b7f616d9
#   Summary Publikations ID: dd43f4be-458e-440b-ae5e-22fe7978ac8c
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/a2f44a65-b500-4901-ab95-cb50b7f616d9/publication-details/dd43f4be-458e-440b-ae5e-22fe7978ac8c mit Parametern: None
# INFO: Details für Projekt 'Muffen & Endverschlüsse BKW Energie AG' (Pub-ID: dd43f4be-458e-440b-ae5e-22fe7978ac8c) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [24/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 9e6997c6-9638-4e42-8feb-39101eb5d7b8
#   Summary Publikations ID: 37193e76-5802-4d3b-9558-97d2c61a9577
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/9e6997c6-9638-4e42-8feb-39101eb5d7b8/publication-details/37193e76-5802-4d3b-9558-97d2c61a9577 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 37193e76-5802-4d3b-9558-97d2c61a9577) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [25/87] Verarbeite Projekt: 'Neubau Schule Wiesental, BKP 250 Sanitäre Anlage Etappe 2'
#   Summary Projekt ID: 5aac2735-2c57-4e5d-80ce-abfc498f718f
#   Summary Publikations ID: b7ca4f3a-3c6a-465c-91cc-b6d28cec6438
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/5aac2735-2c57-4e5d-80ce-abfc498f718f/publication-details/b7ca4f3a-3c6a-465c-91cc-b6d28cec6438 mit Parametern: None
# INFO: Details für Projekt 'Neubau Schule Wiesental, BKP 250 Sanitäre Anlage Etappe 2' (Pub-ID: b7ca4f3a-3c6a-465c-91cc-b6d28cec6438) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [26/87] Verarbeite Projekt: 'Neubau Schule Wiesental, BKP 230 Elektroinstallationen Etappe 2'
#   Summary Projekt ID: 2077d1da-b509-4bd5-a365-d5c7089b5a32
#   Summary Publikations ID: 28361eec-5d01-4951-a271-a33a8ea48405
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/2077d1da-b509-4bd5-a365-d5c7089b5a32/publication-details/28361eec-5d01-4951-a271-a33a8ea48405 mit Parametern: None
# INFO: Details für Projekt 'Neubau Schule Wiesental, BKP 230 Elektroinstallationen Etappe 2' (Pub-ID: 28361eec-5d01-4951-a271-a33a8ea48405) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [27/87] Verarbeite Projekt: 'Neubau Klinikum 2, SKP 364, MTA-Aufzüge'
#   Summary Projekt ID: 8ee64646-9482-4846-b851-a3246b01501a
#   Summary Publikations ID: 6e26a441-f982-4525-8718-db1b3ed0a0ca
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/8ee64646-9482-4846-b851-a3246b01501a/publication-details/6e26a441-f982-4525-8718-db1b3ed0a0ca mit Parametern: None
# INFO: Details für Projekt 'Neubau Klinikum 2, SKP 364, MTA-Aufzüge' (Pub-ID: 6e26a441-f982-4525-8718-db1b3ed0a0ca) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [28/87] Verarbeite Projekt: 'Erweiterung Löschwasserreservoir A9 Bächji, Visperterminen'
#   Summary Projekt ID: 09645829-5049-4bd3-bfa7-2e1fb5829766
#   Summary Publikations ID: 20c88c3f-dbbc-4b02-a610-978513fc7f00
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/09645829-5049-4bd3-bfa7-2e1fb5829766/publication-details/20c88c3f-dbbc-4b02-a610-978513fc7f00 mit Parametern: None
# INFO: Details für Projekt 'Erweiterung Löschwasserreservoir A9 Bächji, Visperterminen' (Pub-ID: 20c88c3f-dbbc-4b02-a610-978513fc7f00) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [29/87] Verarbeite Projekt: 'INFRA21+ - Datacenter Support Services (Remote Hands) '
#   Summary Projekt ID: 99d8331c-ad41-4d52-a5a1-81957dca2804
#   Summary Publikations ID: b3e3e534-127a-4d8c-aacb-912896bd32c7
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/99d8331c-ad41-4d52-a5a1-81957dca2804/publication-details/b3e3e534-127a-4d8c-aacb-912896bd32c7 mit Parametern: None
# INFO: Details für Projekt 'INFRA21+ - Datacenter Support Services (Remote Hands) ' (Pub-ID: b3e3e534-127a-4d8c-aacb-912896bd32c7) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [30/87] Verarbeite Projekt: 'Sanierung Garderobengebäude Strandbad Olten'
#   Summary Projekt ID: 41f1ad4d-af47-40ba-8d58-e8123866384d
#   Summary Publikations ID: 834bc7d4-2207-4f9b-b4bb-3ff7fde5b4ba
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/41f1ad4d-af47-40ba-8d58-e8123866384d/publication-details/834bc7d4-2207-4f9b-b4bb-3ff7fde5b4ba mit Parametern: None
# INFO: Details für Projekt 'Sanierung Garderobengebäude Strandbad Olten' (Pub-ID: 834bc7d4-2207-4f9b-b4bb-3ff7fde5b4ba) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [31/87] Verarbeite Projekt: 'Reinigungsdienstleistung Perron'
#   Summary Projekt ID: 96694e1b-a57e-4e34-8b9a-4e75a69504cf
#   Summary Publikations ID: 17f80977-91c3-4166-aa29-85b7f6fc2caa
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/96694e1b-a57e-4e34-8b9a-4e75a69504cf/publication-details/17f80977-91c3-4166-aa29-85b7f6fc2caa mit Parametern: None
# INFO: Details für Projekt 'Reinigungsdienstleistung Perron' (Pub-ID: 17f80977-91c3-4166-aa29-85b7f6fc2caa) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [32/87] Verarbeite Projekt: 'BKP 214.4 Äussere Bekleidungen, Gesimse, Treppen'
#   Summary Projekt ID: 4ef5802f-e5d8-4153-a841-1309f329744a
#   Summary Publikations ID: 5d77b380-86f4-44ff-8ae0-e206bc8e40a4
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/4ef5802f-e5d8-4153-a841-1309f329744a/publication-details/5d77b380-86f4-44ff-8ae0-e206bc8e40a4 mit Parametern: None
# INFO: Details für Projekt 'BKP 214.4 Äussere Bekleidungen, Gesimse, Treppen' (Pub-ID: 5d77b380-86f4-44ff-8ae0-e206bc8e40a4) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [33/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 6368e9bc-75b1-4605-be95-8613b91e2e15
#   Summary Publikations ID: 39c2743f-89a8-4c9b-895d-b918b5731541
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/6368e9bc-75b1-4605-be95-8613b91e2e15/publication-details/39c2743f-89a8-4c9b-895d-b918b5731541 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 39c2743f-89a8-4c9b-895d-b918b5731541) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [34/87] Verarbeite Projekt: 'BKP 258 Kücheneinrichtungen'
#   Summary Projekt ID: 6c49f9cc-ce80-402a-a317-3bc26520096f
#   Summary Publikations ID: 7d9ede3d-f1b0-43b3-8f73-b1d160c67d02
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/6c49f9cc-ce80-402a-a317-3bc26520096f/publication-details/7d9ede3d-f1b0-43b3-8f73-b1d160c67d02 mit Parametern: None
# INFO: Details für Projekt 'BKP 258 Kücheneinrichtungen' (Pub-ID: 7d9ede3d-f1b0-43b3-8f73-b1d160c67d02) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [35/87] Verarbeite Projekt: 'BKP 224.1 Dichtungsbeläge Flachdächer'
#   Summary Projekt ID: 0015fa9b-2aa5-437c-9f6f-f08997c98d4b
#   Summary Publikations ID: e64b8cb5-02bc-4062-b60b-d5a03cfb70b1
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/0015fa9b-2aa5-437c-9f6f-f08997c98d4b/publication-details/e64b8cb5-02bc-4062-b60b-d5a03cfb70b1 mit Parametern: None
# INFO: Details für Projekt 'BKP 224.1 Dichtungsbeläge Flachdächer' (Pub-ID: e64b8cb5-02bc-4062-b60b-d5a03cfb70b1) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [36/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 607065f9-aac9-4197-8113-c64e277b4627
#   Summary Publikations ID: 11930581-474d-4eac-8b85-3932bf6e88ae
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/607065f9-aac9-4197-8113-c64e277b4627/publication-details/11930581-474d-4eac-8b85-3932bf6e88ae mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 11930581-474d-4eac-8b85-3932bf6e88ae) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [37/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 6594c3c8-a166-49e0-87a5-270b56465345
#   Summary Publikations ID: 68440b55-6e72-473f-9bb7-bc37862a2bc6
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/6594c3c8-a166-49e0-87a5-270b56465345/publication-details/68440b55-6e72-473f-9bb7-bc37862a2bc6 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 68440b55-6e72-473f-9bb7-bc37862a2bc6) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [38/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: cd1acc7a-0d1e-4a11-803e-38a772b9dd46
#   Summary Publikations ID: f0353405-92ba-462d-9206-1574fea8765e
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/cd1acc7a-0d1e-4a11-803e-38a772b9dd46/publication-details/f0353405-92ba-462d-9206-1574fea8765e mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: f0353405-92ba-462d-9206-1574fea8765e) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [39/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 43dca528-50bf-48d4-88f5-d23efa7babd3
#   Summary Publikations ID: e1f19761-e9ff-4795-acca-9ff692171586
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/43dca528-50bf-48d4-88f5-d23efa7babd3/publication-details/e1f19761-e9ff-4795-acca-9ff692171586 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: e1f19761-e9ff-4795-acca-9ff692171586) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [40/87] Verarbeite Projekt: 'GEP 2. Generation'
#   Summary Projekt ID: 29ea7dbb-a387-4c0e-a1a0-b75a0be5ddf0
#   Summary Publikations ID: 12d7ecff-c34e-442f-9d9f-3165d7fb2b1f
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/29ea7dbb-a387-4c0e-a1a0-b75a0be5ddf0/publication-details/12d7ecff-c34e-442f-9d9f-3165d7fb2b1f mit Parametern: None
# INFO: Details für Projekt 'GEP 2. Generation' (Pub-ID: 12d7ecff-c34e-442f-9d9f-3165d7fb2b1f) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [41/87] Verarbeite Projekt: 'Maschineller Gleisabbruch und Werkleitungsbau'
#   Summary Projekt ID: 250ed75a-eeb8-41ff-978b-be49165f0645
#   Summary Publikations ID: cefb58bb-851e-4722-bba6-97df4d234bd7
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/250ed75a-eeb8-41ff-978b-be49165f0645/publication-details/cefb58bb-851e-4722-bba6-97df4d234bd7 mit Parametern: None
# INFO: Details für Projekt 'Maschineller Gleisabbruch und Werkleitungsbau' (Pub-ID: cefb58bb-851e-4722-bba6-97df4d234bd7) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [42/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 06cc1be7-1e39-4edc-a7f1-51f9f1ed0c95
#   Summary Publikations ID: 850b5b26-d7fb-4a3b-b4d2-fc0989f58429
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/06cc1be7-1e39-4edc-a7f1-51f9f1ed0c95/publication-details/850b5b26-d7fb-4a3b-b4d2-fc0989f58429 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 850b5b26-d7fb-4a3b-b4d2-fc0989f58429) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [43/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 95e58528-058f-40a7-8320-bfece96ab80e
#   Summary Publikations ID: 7ecfd105-ef22-43f0-87a6-1a61eab6d8a9
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/95e58528-058f-40a7-8320-bfece96ab80e/publication-details/7ecfd105-ef22-43f0-87a6-1a61eab6d8a9 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 7ecfd105-ef22-43f0-87a6-1a61eab6d8a9) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [44/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 850ac883-49a5-4b97-816e-d17f510522de
#   Summary Publikations ID: 9b301dc8-d709-410b-9ddb-83c48c488f91
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/850ac883-49a5-4b97-816e-d17f510522de/publication-details/9b301dc8-d709-410b-9ddb-83c48c488f91 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 9b301dc8-d709-410b-9ddb-83c48c488f91) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [45/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: b549ceaf-0aae-4cf2-a499-c7422e13fff5
#   Summary Publikations ID: 85e18544-9b5b-4c55-b8b8-a279ff2c22ea
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/b549ceaf-0aae-4cf2-a499-c7422e13fff5/publication-details/85e18544-9b5b-4c55-b8b8-a279ff2c22ea mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 85e18544-9b5b-4c55-b8b8-a279ff2c22ea) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [46/87] Verarbeite Projekt: 'N01.12 MP-190067 - BSA Réf signal. surv. Bardonnex-Coppet - Rénovation des LS de GE (ID 11098)'
#   Summary Projekt ID: 150e7128-ff9a-4543-98a6-c3f9ca1d3bd5
#   Summary Publikations ID: 1073cd1e-1191-47c9-a900-1eee147c0dd5
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/150e7128-ff9a-4543-98a6-c3f9ca1d3bd5/publication-details/1073cd1e-1191-47c9-a900-1eee147c0dd5 mit Parametern: None
# INFO: Details für Projekt 'N01.12 MP-190067 - BSA Réf signal. surv. Bardonnex-Coppet - Rénovation des LS de GE (ID 11098)' (Pub-ID: 1073cd1e-1191-47c9-a900-1eee147c0dd5) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [47/87] Verarbeite Projekt: 'Beschaffungsprojekt «Léman-Express III»'
#   Summary Projekt ID: 945729c4-1eca-49c2-8eb8-12110cf5b840
#   Summary Publikations ID: e079c2c2-758f-41d6-baef-42ac49c3f416
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/945729c4-1eca-49c2-8eb8-12110cf5b840/publication-details/e079c2c2-758f-41d6-baef-42ac49c3f416 mit Parametern: None
# INFO: Details für Projekt 'Beschaffungsprojekt «Léman-Express III»' (Pub-ID: e079c2c2-758f-41d6-baef-42ac49c3f416) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [48/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: b0cb7af9-b78f-4860-8b5f-b27e7900e553
#   Summary Publikations ID: c5a8ed6d-c7f1-4687-a5d9-94b18f81dbf1
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/b0cb7af9-b78f-4860-8b5f-b27e7900e553/publication-details/c5a8ed6d-c7f1-4687-a5d9-94b18f81dbf1 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: c5a8ed6d-c7f1-4687-a5d9-94b18f81dbf1) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [49/87] Verarbeite Projekt: 'Erweiterung und Neubau Turnhalle Schulanlage Steig, Aushub'
#   Summary Projekt ID: d0256f96-48a3-4b92-ba06-33744c624a19
#   Summary Publikations ID: 19d5aca1-0b71-4830-ba40-63b3ff6b0ab4
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/d0256f96-48a3-4b92-ba06-33744c624a19/publication-details/19d5aca1-0b71-4830-ba40-63b3ff6b0ab4 mit Parametern: None
# INFO: Details für Projekt 'Erweiterung und Neubau Turnhalle Schulanlage Steig, Aushub' (Pub-ID: 19d5aca1-0b71-4830-ba40-63b3ff6b0ab4) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [50/87] Verarbeite Projekt: 'GEP Massnahme Bahnstrasse '
#   Summary Projekt ID: 22e53a9f-fabf-49f7-b2c4-1142739442b2
#   Summary Publikations ID: b8efdfa6-121b-483e-8a4a-0d8f0674fc0c
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/22e53a9f-fabf-49f7-b2c4-1142739442b2/publication-details/b8efdfa6-121b-483e-8a4a-0d8f0674fc0c mit Parametern: None
# INFO: Details für Projekt 'GEP Massnahme Bahnstrasse ' (Pub-ID: b8efdfa6-121b-483e-8a4a-0d8f0674fc0c) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [51/87] Verarbeite Projekt: 'Autobahn A9, Teilstrecke Siders Ost – Leuk/Susten Ost, Versetzen Gasleitung, Baulos L10162'
#   Summary Projekt ID: 8450d8c5-628b-4d9b-863e-61a1fa295943
#   Summary Publikations ID: 301776e9-2107-4cde-a5cc-0673fe60a85a
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/8450d8c5-628b-4d9b-863e-61a1fa295943/publication-details/301776e9-2107-4cde-a5cc-0673fe60a85a mit Parametern: None
# INFO: Details für Projekt 'Autobahn A9, Teilstrecke Siders Ost – Leuk/Susten Ost, Versetzen Gasleitung, Baulos L10162' (Pub-ID: 301776e9-2107-4cde-a5cc-0673fe60a85a) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [52/87] Verarbeite Projekt: '3870 NUCLEO - Omnichannel-Lösung für das CVC'
#   Summary Projekt ID: fad8b09c-5a75-4f17-97fb-98783edcbdaf
#   Summary Publikations ID: 75f8c840-d593-4efb-816e-c99c590596a1
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/fad8b09c-5a75-4f17-97fb-98783edcbdaf/publication-details/75f8c840-d593-4efb-816e-c99c590596a1 mit Parametern: None
# INFO: Details für Projekt '3870 NUCLEO - Omnichannel-Lösung für das CVC' (Pub-ID: 75f8c840-d593-4efb-816e-c99c590596a1) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [53/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: f4177d84-a8b9-4c03-9f18-ee79b5fbc95d
#   Summary Publikations ID: 6a87c7c3-7f83-411a-92d8-b2ab2631dfaa
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/f4177d84-a8b9-4c03-9f18-ee79b5fbc95d/publication-details/6a87c7c3-7f83-411a-92d8-b2ab2631dfaa mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 6a87c7c3-7f83-411a-92d8-b2ab2631dfaa) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [54/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 755740f7-22f0-4a79-9dcc-605dd1425a1b
#   Summary Publikations ID: ed370717-775f-4b89-af9e-ced6a13f91ad
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/755740f7-22f0-4a79-9dcc-605dd1425a1b/publication-details/ed370717-775f-4b89-af9e-ced6a13f91ad mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: ed370717-775f-4b89-af9e-ced6a13f91ad) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [55/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 471ba8d1-c4c9-4d59-b1e5-3ae681b3c2a5
#   Summary Publikations ID: 5d9bccbd-19ec-48a6-8085-d236429a7d61
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/471ba8d1-c4c9-4d59-b1e5-3ae681b3c2a5/publication-details/5d9bccbd-19ec-48a6-8085-d236429a7d61 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 5d9bccbd-19ec-48a6-8085-d236429a7d61) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [56/87] Verarbeite Projekt: 'Hauptstandort Sanität, Gesamtsanierung, Hebelstrasse 51/53 - BKP 273.0 Innentüren aus Holz'
#   Summary Projekt ID: d12bb27b-e1ae-408a-80ad-c81e784de6db
#   Summary Publikations ID: 0bfeb17f-1438-49ac-98fa-e824daec9d3a
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/d12bb27b-e1ae-408a-80ad-c81e784de6db/publication-details/0bfeb17f-1438-49ac-98fa-e824daec9d3a mit Parametern: None
# INFO: Details für Projekt 'Hauptstandort Sanität, Gesamtsanierung, Hebelstrasse 51/53 - BKP 273.0 Innentüren aus Holz' (Pub-ID: 0bfeb17f-1438-49ac-98fa-e824daec9d3a) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [57/87] Verarbeite Projekt: 'MP 3441 St. Albanteich-Promenade, Abschnitt Schwarzpark, Baumeister'
#   Summary Projekt ID: 7c973432-f204-415c-81a3-0f54a099f807
#   Summary Publikations ID: 26662686-79e5-4150-9922-e45043004d9f
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/7c973432-f204-415c-81a3-0f54a099f807/publication-details/26662686-79e5-4150-9922-e45043004d9f mit Parametern: None
# INFO: Details für Projekt 'MP 3441 St. Albanteich-Promenade, Abschnitt Schwarzpark, Baumeister' (Pub-ID: 26662686-79e5-4150-9922-e45043004d9f) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [58/87] Verarbeite Projekt: 'Claragraben 95, Umbau und Sanierung, BKP 211 Baumeisterarbeiten mit Schadstoffsanierung'
#   Summary Projekt ID: 3287fb91-01ed-4a25-a2c3-aaa16e540163
#   Summary Publikations ID: 89260b4e-0329-4f0e-b954-bcfdb2206a2c
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/3287fb91-01ed-4a25-a2c3-aaa16e540163/publication-details/89260b4e-0329-4f0e-b954-bcfdb2206a2c mit Parametern: None
# INFO: Details für Projekt 'Claragraben 95, Umbau und Sanierung, BKP 211 Baumeisterarbeiten mit Schadstoffsanierung' (Pub-ID: 89260b4e-0329-4f0e-b954-bcfdb2206a2c) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [59/87] Verarbeite Projekt: 'Alpenrhein: Unterhaltsmassnahmen "gesetzter" Blockwurf Winter 2025/26 inkl. Steinlieferungen'
#   Summary Projekt ID: 369043f5-dbb7-4e61-b6f5-cb172098a5b6
#   Summary Publikations ID: e8412eb2-668a-4cab-afc8-b78464eac9cd
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/369043f5-dbb7-4e61-b6f5-cb172098a5b6/publication-details/e8412eb2-668a-4cab-afc8-b78464eac9cd mit Parametern: None
# INFO: Details für Projekt 'Alpenrhein: Unterhaltsmassnahmen "gesetzter" Blockwurf Winter 2025/26 inkl. Steinlieferungen' (Pub-ID: e8412eb2-668a-4cab-afc8-b78464eac9cd) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [60/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: d0338e9c-0cf2-425e-898a-471a4ccc92da
#   Summary Publikations ID: 482a1fc6-3e9a-481e-a50a-8366277e2d28
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/d0338e9c-0cf2-425e-898a-471a4ccc92da/publication-details/482a1fc6-3e9a-481e-a50a-8366277e2d28 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 482a1fc6-3e9a-481e-a50a-8366277e2d28) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [61/87] Verarbeite Projekt: 'IMA ZV Kaserne Zürich, Gesamtinstandsetzung/Umnutzung, BKP 226-01 Fassadenputze historisch'
#   Summary Projekt ID: 881c6075-bfb4-4126-8b16-befe2bd8890f
#   Summary Publikations ID: cc9b7486-b640-4f25-8352-96c6a80397ad
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/881c6075-bfb4-4126-8b16-befe2bd8890f/publication-details/cc9b7486-b640-4f25-8352-96c6a80397ad mit Parametern: None
# INFO: Details für Projekt 'IMA ZV Kaserne Zürich, Gesamtinstandsetzung/Umnutzung, BKP 226-01 Fassadenputze historisch' (Pub-ID: cc9b7486-b640-4f25-8352-96c6a80397ad) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [62/87] Verarbeite Projekt: 'IMA ZV Kaserne Zürich, Gesamtinstandsetzung/Umnutzung, BKP 226-02 Fassadenputze neu'
#   Summary Projekt ID: ecba98d7-5312-427b-977b-861be8a0ec46
#   Summary Publikations ID: 90259acc-8e0c-4754-9f09-13a19009063e
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/ecba98d7-5312-427b-977b-861be8a0ec46/publication-details/90259acc-8e0c-4754-9f09-13a19009063e mit Parametern: None
# INFO: Details für Projekt 'IMA ZV Kaserne Zürich, Gesamtinstandsetzung/Umnutzung, BKP 226-02 Fassadenputze neu' (Pub-ID: 90259acc-8e0c-4754-9f09-13a19009063e) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [63/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: ebb96238-84a8-4446-8fb8-475045bd7228
#   Summary Publikations ID: 7036b96e-d486-40e9-830b-3cc772cd33b1
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/ebb96238-84a8-4446-8fb8-475045bd7228/publication-details/7036b96e-d486-40e9-830b-3cc772cd33b1 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 7036b96e-d486-40e9-830b-3cc772cd33b1) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [64/87] Verarbeite Projekt: 'ARA Briglina Realisierung BKP 211.13 Baumeister Auslaufleitung (Microtunneling)'
#   Summary Projekt ID: b95a2db1-f171-4436-81db-c182b64a26a4
#   Summary Publikations ID: 1c85f54d-5089-4840-9f0f-8831d0ea5784
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/b95a2db1-f171-4436-81db-c182b64a26a4/publication-details/1c85f54d-5089-4840-9f0f-8831d0ea5784 mit Parametern: None
# INFO: Details für Projekt 'ARA Briglina Realisierung BKP 211.13 Baumeister Auslaufleitung (Microtunneling)' (Pub-ID: 1c85f54d-5089-4840-9f0f-8831d0ea5784) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [65/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 1814a425-289d-4a8f-9db8-deb88c3c9631
#   Summary Publikations ID: a28baca3-de92-4b6a-8c09-af00a6e74a4f
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/1814a425-289d-4a8f-9db8-deb88c3c9631/publication-details/a28baca3-de92-4b6a-8c09-af00a6e74a4f mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: a28baca3-de92-4b6a-8c09-af00a6e74a4f) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [66/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: ff3b8738-9b8e-44aa-aa5d-1a61402e5138
#   Summary Publikations ID: c09d0a21-b4b0-4abf-ab91-7e9cba848fff
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/ff3b8738-9b8e-44aa-aa5d-1a61402e5138/publication-details/c09d0a21-b4b0-4abf-ab91-7e9cba848fff mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: c09d0a21-b4b0-4abf-ab91-7e9cba848fff) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [67/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 57f6dfc6-b156-40df-9c78-f4cee79bd738
#   Summary Publikations ID: e2612979-2cdb-4f7d-8e18-ac7d8a0b077e
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/57f6dfc6-b156-40df-9c78-f4cee79bd738/publication-details/e2612979-2cdb-4f7d-8e18-ac7d8a0b077e mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: e2612979-2cdb-4f7d-8e18-ac7d8a0b077e) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [68/87] Verarbeite Projekt: 'Ausbau Haus 09 zu Forschung - SKP 359 Laborausstattungen'
#   Summary Projekt ID: bc720527-51db-4711-8fc3-52e38f007812
#   Summary Publikations ID: 218830eb-2fb8-4553-bd3e-c495ad789b23
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/bc720527-51db-4711-8fc3-52e38f007812/publication-details/218830eb-2fb8-4553-bd3e-c495ad789b23 mit Parametern: None
# INFO: Details für Projekt 'Ausbau Haus 09 zu Forschung - SKP 359 Laborausstattungen' (Pub-ID: 218830eb-2fb8-4553-bd3e-c495ad789b23) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [69/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 20361cf9-2e3e-48f0-80fe-e351fa7c8a7c
#   Summary Publikations ID: 959b8167-2808-4d68-8ec2-a51c8f843fb0
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/20361cf9-2e3e-48f0-80fe-e351fa7c8a7c/publication-details/959b8167-2808-4d68-8ec2-a51c8f843fb0 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 959b8167-2808-4d68-8ec2-a51c8f843fb0) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [70/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 75852ada-e295-4001-87a6-e3df7885b37f
#   Summary Publikations ID: ece0c4bd-819f-4856-a352-d73bfc69c7b7
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/75852ada-e295-4001-87a6-e3df7885b37f/publication-details/ece0c4bd-819f-4856-a352-d73bfc69c7b7 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: ece0c4bd-819f-4856-a352-d73bfc69c7b7) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [71/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 9b39636c-b354-46ab-9712-ed9f9caa6f8c
#   Summary Publikations ID: 1cc47c34-bdf5-4641-919e-f39203dc1151
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/9b39636c-b354-46ab-9712-ed9f9caa6f8c/publication-details/1cc47c34-bdf5-4641-919e-f39203dc1151 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 1cc47c34-bdf5-4641-919e-f39203dc1151) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [72/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 511e1dc4-a67b-4549-8084-e5ab20ea3d30
#   Summary Publikations ID: 731940a5-5b89-4fca-849a-3872520727fb
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/511e1dc4-a67b-4549-8084-e5ab20ea3d30/publication-details/731940a5-5b89-4fca-849a-3872520727fb mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 731940a5-5b89-4fca-849a-3872520727fb) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [73/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: a57e0e1d-4d45-4aaa-b7bd-a135d53363d1
#   Summary Publikations ID: cded3709-3e84-4a48-9ab6-50a7979d8e07
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/a57e0e1d-4d45-4aaa-b7bd-a135d53363d1/publication-details/cded3709-3e84-4a48-9ab6-50a7979d8e07 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: cded3709-3e84-4a48-9ab6-50a7979d8e07) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [74/87] Verarbeite Projekt: 'Claragraben 95, Umbau und Sanierung, BKP 211.1 Gerüste'
#   Summary Projekt ID: eff20b10-d242-4a0a-aaab-bbd381e9acb6
#   Summary Publikations ID: d8f6b646-11aa-429f-985e-8076b354eab6
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/eff20b10-d242-4a0a-aaab-bbd381e9acb6/publication-details/d8f6b646-11aa-429f-985e-8076b354eab6 mit Parametern: None
# INFO: Details für Projekt 'Claragraben 95, Umbau und Sanierung, BKP 211.1 Gerüste' (Pub-ID: d8f6b646-11aa-429f-985e-8076b354eab6) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [75/87] Verarbeite Projekt: 'Primarschulanlage Boppartshof, Neubau Trakt F (BKP 221.1 Fenster in Holz/Metall)'
#   Summary Projekt ID: 9e24d375-3084-42f7-927d-b1b237b5e68e
#   Summary Publikations ID: 559c6311-b003-4746-a684-5819fc0f3456
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/9e24d375-3084-42f7-927d-b1b237b5e68e/publication-details/559c6311-b003-4746-a684-5819fc0f3456 mit Parametern: None
# INFO: Details für Projekt 'Primarschulanlage Boppartshof, Neubau Trakt F (BKP 221.1 Fenster in Holz/Metall)' (Pub-ID: 559c6311-b003-4746-a684-5819fc0f3456) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [76/87] Verarbeite Projekt: 'Kleinlöschfahrzeug (KLF)'
#   Summary Projekt ID: af7e6eac-e04f-46c8-be41-5b8d3991d016
#   Summary Publikations ID: 6501998a-09ee-440f-b9c0-bd361a1aabeb
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/af7e6eac-e04f-46c8-be41-5b8d3991d016/publication-details/6501998a-09ee-440f-b9c0-bd361a1aabeb mit Parametern: None
# INFO: Details für Projekt 'Kleinlöschfahrzeug (KLF)' (Pub-ID: 6501998a-09ee-440f-b9c0-bd361a1aabeb) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [77/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: c2a1eb38-c82e-48f2-8d0f-06787418d5d2
#   Summary Publikations ID: 90825419-572c-48bd-8356-2399db6fa114
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/c2a1eb38-c82e-48f2-8d0f-06787418d5d2/publication-details/90825419-572c-48bd-8356-2399db6fa114 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 90825419-572c-48bd-8356-2399db6fa114) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [78/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 98e5eaf2-605c-4a68-a523-9bff72e5263c
#   Summary Publikations ID: 05bfa79b-e22c-4ac6-a632-c7a1e57678fe
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/98e5eaf2-605c-4a68-a523-9bff72e5263c/publication-details/05bfa79b-e22c-4ac6-a632-c7a1e57678fe mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 05bfa79b-e22c-4ac6-a632-c7a1e57678fe) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [79/87] Verarbeite Projekt: 'Primarschulanlage Boppartshof, Neubau Trakt F (BKP 250 Sanitäranlagen)'
#   Summary Projekt ID: 55f3e89f-ca93-4e0f-9038-f06a063a1914
#   Summary Publikations ID: dabae5b8-5555-4569-8080-f2e6736b6d81
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/55f3e89f-ca93-4e0f-9038-f06a063a1914/publication-details/dabae5b8-5555-4569-8080-f2e6736b6d81 mit Parametern: None
# INFO: Details für Projekt 'Primarschulanlage Boppartshof, Neubau Trakt F (BKP 250 Sanitäranlagen)' (Pub-ID: dabae5b8-5555-4569-8080-f2e6736b6d81) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [80/87] Verarbeite Projekt: 'Primarschulanlage Boppartshof, Neubau Trakt F (BKP 230 Elektroanlagen)'
#   Summary Projekt ID: f4935441-0924-4e15-a5a9-acb12c7f4722
#   Summary Publikations ID: a4099b1d-5ef1-4daa-beda-ce15e78a785b
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/f4935441-0924-4e15-a5a9-acb12c7f4722/publication-details/a4099b1d-5ef1-4daa-beda-ce15e78a785b mit Parametern: None
# INFO: Details für Projekt 'Primarschulanlage Boppartshof, Neubau Trakt F (BKP 230 Elektroanlagen)' (Pub-ID: a4099b1d-5ef1-4daa-beda-ce15e78a785b) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [81/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 5e008158-3d8a-4cde-a936-0da93f84e47c
#   Summary Publikations ID: 7b0c7b4c-e517-4bdc-9e59-c092c2bf1d28
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/5e008158-3d8a-4cde-a936-0da93f84e47c/publication-details/7b0c7b4c-e517-4bdc-9e59-c092c2bf1d28 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 7b0c7b4c-e517-4bdc-9e59-c092c2bf1d28) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [82/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: 76f4a313-4526-4f3e-a48d-0006cf8ccfba
#   Summary Publikations ID: e2fc7bf3-1733-403f-9340-6572f27c024c
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/76f4a313-4526-4f3e-a48d-0006cf8ccfba/publication-details/e2fc7bf3-1733-403f-9340-6572f27c024c mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: e2fc7bf3-1733-403f-9340-6572f27c024c) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [83/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: dfb95417-6606-406f-9b90-ef2c55ade8aa
#   Summary Publikations ID: 7fa1f981-9119-41e8-a578-f10ebabf1088
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/dfb95417-6606-406f-9b90-ef2c55ade8aa/publication-details/7fa1f981-9119-41e8-a578-f10ebabf1088 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: 7fa1f981-9119-41e8-a578-f10ebabf1088) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [84/87] Verarbeite Projekt: 'EZ Entfelden, Heizung und Sanitär'
#   Summary Projekt ID: 535ce729-4983-4f68-960b-ee557d086bd1
#   Summary Publikations ID: 8bac031c-88f8-4e13-81a4-e7a44cdada0d
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/535ce729-4983-4f68-960b-ee557d086bd1/publication-details/8bac031c-88f8-4e13-81a4-e7a44cdada0d mit Parametern: None
# INFO: Details für Projekt 'EZ Entfelden, Heizung und Sanitär' (Pub-ID: 8bac031c-88f8-4e13-81a4-e7a44cdada0d) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [85/87] Verarbeite Projekt: 'None'
#   Summary Projekt ID: a085eb91-0b9d-4704-a136-6d2e32248a18
#   Summary Publikations ID: d7817105-5d98-48c9-89d4-d58641b377f8
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/a085eb91-0b9d-4704-a136-6d2e32248a18/publication-details/d7817105-5d98-48c9-89d4-d58641b377f8 mit Parametern: None
# INFO: Details für Projekt 'None' (Pub-ID: d7817105-5d98-48c9-89d4-d58641b377f8) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [86/87] Verarbeite Projekt: 'Beleuchtungssanierung öffentlicher Gebäude der Gemeinde Seengen'
#   Summary Projekt ID: 9e863ba5-0f73-4648-aecf-98f01bf5de23
#   Summary Publikations ID: ebbe75e6-22a0-41ff-a87b-8e0716972c85
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/9e863ba5-0f73-4648-aecf-98f01bf5de23/publication-details/ebbe75e6-22a0-41ff-a87b-8e0716972c85 mit Parametern: None
# INFO: Details für Projekt 'Beleuchtungssanierung öffentlicher Gebäude der Gemeinde Seengen' (Pub-ID: ebbe75e6-22a0-41ff-a87b-8e0716972c85) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# [87/87] Verarbeite Projekt: 'UW Riddes (Valgrid); 1 Stück 275-MVA-Dreiphasen-Netztransformator als Phasenschiebertransformator (220/65 kV) + 1 Stück als Option'
#   Summary Projekt ID: b46df40f-9ab3-4c69-90b2-38d1624c15f5
#   Summary Publikations ID: ebbcd6a7-6923-4d25-acd7-0d25dfe38d66
# INFO: Rufe Simap API auf: https://simap.ch/api/publications/v1/project/b46df40f-9ab3-4c69-90b2-38d1624c15f5/publication-details/ebbcd6a7-6923-4d25-acd7-0d25dfe38d66 mit Parametern: None
# INFO: Details für Projekt 'UW Riddes (Valgrid); 1 Stück 275-MVA-Dreiphasen-Netztransformator als Phasenschiebertransformator (220/65 kV) + 1 Stück als Option' (Pub-ID: ebbcd6a7-6923-4d25-acd7-0d25dfe38d66) erfolgreich abgerufen.
# INFO: Warte 1 Sekunde vor dem nächsten API-Aufruf...
#
# --- Detailabruf abgeschlossen ---
# INFO: Erfolgreich Details für 87 von 87 Projekten abgerufen.
#
# --- Erste(s) abgerufene(s) Projektdetail(s) zur Ansicht (max. 1) ---
# {
#   "project-info": {
#     "stateContractArea": false,
#     "dialog": "no",
#     "documentsWithCosts": "no",
#     "publicationTed": false,
#     "procOfficeAddress": {
#       "postalCode": "1700",
#       "countryId": "CH",
#       "cantonId": "FR",
#       "id": "6712b66a-582e-4d65-a305-9c66f3a50e44",
#       "name": {
#         "de": null,
#         "en": null,
#         "fr": "Ribi SA",
#         "it": null
#       },
#       "contactPerson": {
#         "de": null,
#         "en": null,
#         "fr": "Yannick Ribi",
#         "it": null
#       },
#       "phone": "+41263221217",
#       "email": "fribourg@ribi.ch",
#       "url": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       },
#       "reference": null,
#       "street": {
#         "de": null,
#         "en": null,
#         "fr": "Grand'Places 14",
#         "it": null
#       },
#       "city": {
#         "de": null,
#         "en": null,
#         "fr": "Fribourg",
#         "it": null
#       }
#     },
#     "procurementRecipientAddress": {
#       "postalCode": null,
#       "countryId": "CH",
#       "cantonId": "FR",
#       "id": "df2e0e85-bc9d-4ad8-8ec2-72e0dae7cd5b",
#       "name": {
#         "de": null,
#         "en": null,
#         "fr": "Commune de Belmont-Broye",
#         "it": null
#       },
#       "contactPerson": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       },
#       "phone": null,
#       "email": null,
#       "url": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       },
#       "reference": null,
#       "street": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       },
#       "city": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       }
#     },
#     "title": {
#       "de": null,
#       "en": null,
#       "fr": "Chandon - Mise à ciel ouvert",
#       "it": null
#     },
#     "documentsLanguages": [
#       "fr"
#     ],
#     "documentsSourceType": "documents_source_simap",
#     "offerLanguages": [
#       "fr"
#     ],
#     "offerTypes": [
#       "offer_external"
#     ],
#     "publicationLanguages": [
#       "fr"
#     ],
#     "processType": "open",
#     "orderType": "construction",
#     "participantLotsLimitation": null,
#     "participantLotsLimitationNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "dialogNote": null,
#     "documentsCosts": {
#       "currency": null,
#       "price": null
#     },
#     "documentsCostsNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "documentsLanguagesNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "documentsSourceEmail": null,
#     "documentsSourceUrl": null,
#     "documentsSourceNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "offerSpecificNote": null,
#     "offerDigitalExternalPlatformUrl": null,
#     "documentsSourceAddress": null,
#     "offerAddress": {
#       "postalCode": "1564",
#       "countryId": "CH",
#       "cantonId": null,
#       "id": "59820165-cb76-4025-b235-3d1c73c4c902",
#       "name": {
#         "de": null,
#         "en": null,
#         "fr": "Commune de Belmont-Broye",
#         "it": null
#       },
#       "contactPerson": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       },
#       "phone": null,
#       "email": null,
#       "url": {
#         "de": null,
#         "en": null,
#         "fr": null,
#         "it": null
#       },
#       "reference": null,
#       "street": {
#         "de": null,
#         "en": null,
#         "fr": "Pré-de-la-Cour 4",
#         "it": null
#       },
#       "city": {
#         "de": null,
#         "en": null,
#         "fr": "Domdidier",
#         "it": null
#       }
#     },
#     "publicationLanguagesComment": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     }
#   },
#   "procurement": {
#     "orderDescription": {
#       "de": null,
#       "en": null,
#       "fr": "<p>Ruisseau du Chandon</p><p>Remise à ciel ouvert et passage sous la route communale</p>",
#       "it": null
#     },
#     "processType": "open",
#     "orderType": "construction",
#     "additionalCpvCodes": [],
#     "bkpCodes": [],
#     "ebkphCodes": [],
#     "ebkptCodes": [],
#     "npkCodes": [],
#     "oagCodes": [],
#     "constructionType": "execution",
#     "constructionCategory": "civil_engineering",
#     "orderAddressOnlyDescription": "no",
#     "orderAddressDescription": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "executionDeadlineType": "not_specified",
#     "executionPeriod": null,
#     "executionDays": null,
#     "executionNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "variants": "no",
#     "variantsNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "partialOffers": "no",
#     "partialOffersNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "orderAddress": {
#       "countryId": "CH",
#       "cantonId": "FR",
#       "postalCode": "1773",
#       "city": {
#         "de": null,
#         "en": null,
#         "fr": "Chandon",
#         "it": null
#       }
#     },
#     "contractDeadlineType": "days_after",
#     "contractPeriod": null,
#     "contractDays": 360,
#     "canContractBeExtended": "yes",
#     "canContractBeExtendedNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "options": "no",
#     "optionsNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "cpvCode": {
#       "code": "45000000",
#       "label": {
#         "de": "Bauarbeiten",
#         "en": "Construction work",
#         "fr": "Travaux de construction",
#         "it": "Lavori di costruzione"
#       }
#     }
#   },
#   "terms": {
#     "termsType": "in_documents",
#     "termsCriteria": [],
#     "termsCriteriaAsPDF": false,
#     "consortiumAllowed": "no",
#     "consortiumMultiApplicationAllowed": "no",
#     "subContractorAllowed": "not_specified",
#     "subContractorMultiApplicationAllowed": "not_specified",
#     "processType": "open",
#     "orderType": "construction",
#     "preInvolvedVendor": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "termsOfBusiness": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "termsOfPayment": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "includedCosts": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "securityDeposits": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "nonWTORequirements": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "walkThroughNotes": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "termsNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "otherRequirements": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "consortiumNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "subContractorNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "remediesNotice": {
#       "de": null,
#       "en": null,
#       "fr": "Cette décision peut, dans un délai de 20 jours dès la présente publication, faire l'objet d'un recours auprès du Tribunal cantonal, section administrative, Rue des Augustins 3, Case postale 1654, 1701 Fribourg.",
#       "it": null
#     }
#   },
#   "dates": {
#     "qnaRoundSourceType": "no_qna_rounds",
#     "offerValidityDeadlineType": "not_specified",
#     "offerValidityNotes": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "reductionMinimumOfferDeadline": false,
#     "publicOfferOpening": "no",
#     "qnas": [],
#     "otherAppointments": [],
#     "processType": "open",
#     "orderType": "construction",
#     "publicationDate": "2025-05-28",
#     "initialPublicationDate": null,
#     "publicationDateForecast": null,
#     "offerDeadline": "2025-07-07T11:00:00+02:00",
#     "specificDeadlinesAndFormalRequirements": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "documentsAvailable": null,
#     "expressionOfInterestUntil": null,
#     "offerValidityDeadlineDate": null,
#     "offerValidityDeadlineDays": null,
#     "offerOpening": null,
#     "offerOpeningNotes": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "offerOpeningPostalCode": null,
#     "offerOpeningCity": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     }
#   },
#   "id": "4b400201-3a77-4daa-8de3-faf003175cdb",
#   "type": "tender",
#   "projectType": "tender",
#   "publishers": [
#     {
#       "id": "c92c5781-c89a-4f93-94b1-f2061c35e556",
#       "name": "simap.ch"
#     }
#   ],
#   "correction": null,
#   "referencingPub": null,
#   "invitedVendors": null,
#   "lots": [],
#   "criteria": {
#     "qualificationCriteriaInDocuments": "yes",
#     "qualificationCriteriaAsPDF": false,
#     "qualificationCriteria": [],
#     "awardCriteriaSelection": "criteria_in_documents",
#     "awardCriteria": [],
#     "processType": "open",
#     "orderType": "construction",
#     "qualificationCriteriaNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "awardCriteriaNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     }
#   },
#   "base": {
#     "corrected": false,
#     "cpvCode": {
#       "code": "45000000",
#       "label": {
#         "de": "Bauarbeiten",
#         "en": "Construction work",
#         "fr": "Travaux de construction",
#         "it": "Lavori di costruzione"
#       }
#     },
#     "orderType": "construction",
#     "lots": [],
#     "publicationTed": false,
#     "id": "4b400201-3a77-4daa-8de3-faf003175cdb",
#     "title": {
#       "de": null,
#       "en": null,
#       "fr": "Chandon - Mise à ciel ouvert",
#       "it": null
#     },
#     "projectType": "tender",
#     "processType": "open",
#     "lotsType": "without",
#     "stateContractArea": false,
#     "type": "tender",
#     "publicationNumber": "12012-01",
#     "projectId": "0712ca2c-7429-4f83-ac51-903b7358bc0f",
#     "publicationDate": "2025-05-28",
#     "creationLanguage": "fr",
#     "translationLanguages": [],
#     "procOfficeId": "4dbdd043-a8df-42f1-8fa8-317fdb1713ec",
#     "publishers": [
#       "c92c5781-c89a-4f93-94b1-f2061c35e556"
#     ],
#     "participantLotsLimitation": null,
#     "participantLotsLimitationNote": {
#       "de": null,
#       "en": null,
#       "fr": null,
#       "it": null
#     },
#     "correctedPubId": null,
#     "initialPublicationDate": null,
#     "referencingPubId": null,
#     "cpcCode": null,
#     "projectNumber": "12012"
#   },
#   "ted": null
# }

# %%
company_profile = {
    "name": "Mesoneer GmbH",
    "domains": [
        "Identifikationssoftware",
        "Engineering (Workflow-Automation, RPA, Data Processing, Data-Plattform-Lösungen)",
        "AI & Data (Data Governance, Data Strategy, AI-Anwendungen)"
    ],
    "expertise": [
        "Process automatisation","Data Streaming","Data Plattforms",
        "Workflow Engines","IDP","RPA","Cloud","AI And GenAI",
        "Data Engineering","Data Governance and Strategy",
        "Identification Software","Kyc & Onboarding solutions"
    ],
    "technologies": ["BPMN 2.0", "Camunda BPM", "Axon Ivy", "Flowable", 
                     "Apache Kafka", "UiPath", "Microsoft Power Automate",
                     "Apache","Azure","Python","JAVA"],
    "max_contract_value_eur": 500_000
}


# 2. Function-Definition inklusive neuer Klassifikations-Felder
functions = [
    {
        "name": "enrich_project",
        "description": (
            "Analysiere ein SIMAP-Projekt, fasse es kurz zusammen, "
            "extrahiere nur deutsche Werte, ordne es einem Team zu "
            "(Products, Engineering, Data&AI), gib einen Apply-Score 1–10 in wie fern wir geignet sind, "
            "und liste fehlende Felder als MissingInfo auf."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "summary": {"type": "string"},
                "project": {
                    "type": "object",
                    "properties": {
                        "title_de": {"type": "string"},
                        "customer": {"type": "string"},
                        "location": {"type": "string"},
                        "projectNumber": {"type": "string"},
                        "projectId":{"type": "string"},
                        "publicationDate": {"type": "string"},
                        "offerDeadline": {"type": "string"},
                        "contract_start": {"type": "string"},
                        "qna_deadline":{"type": "string"},
                        "cpvCode": {
                            "type": "object",
                            "properties": {
                                "code":     {"type": "string"},
                                "label_de": {"type": "string"}
                            },
                            "required": ["code","label_de"]
                        }
                    },
                    "required": [
                        "qna_deadline,title_de","customer","location","projectId"
                        "publicationDate","offerDeadline","contract_start","cpvCode","projectNumber"
                    ]
                },
                "team": {"type": "string", "enum": ["Products","Engineering","Data&AI"]},
                "apply_score": {
                    "type": "integer",
                    "description": "1–10, in wie fern sich eine Bewerbung lohnt auf Basis unserer Expertise,Technologien und Unternehmensprofil.",
                },
                "missing_info": {
                    "type": "array",
                    "items": {"type": "string"},
                    "description": "Welche relevanten Felder im JSON fehlten"
                }
            },
            "required": ["summary","project","team","apply_score","missing_info"]
        }
    }
]


# --- 2. Einzel-Projekt-Analyzer -------------------------------------------
def enrich_project(full_proj: dict, comp_profile: dict) -> dict:

    system_content = f"""
        Du bist RFP-Analyst für Mesoneer ag. Mesoneer ist Experte für:
        • Identifikationssoftware
        • Engineering (Automation, Data Processing, Plattformen)
        • AI & Data (Data Governance, Strategie, AI)

        Nutze nur die Felder aus dem SIMAP-JSON, die auf Deutsch vorliegen. Analysiere so:

        1. Schreibe eine kompakte Zusammenfassung (2–3 Sätze) in Deutsch.
        2. Extrahiere genau diese Felder aus dem JSON:
        • title_de, customer, location, publicationDate, offerDeadline, contract_start, cpvCode (code+label_de),qna_deadline,projectNumber,projectId
        3. Ordne das Projekt einem Team zu: Products, Engineering oder Data&AI.
        4. Vergib einen Apply-Score von 1–10, basierend auf:
        – Übereinstimmung mit unserem Profil (Domains, Expertise, Technologies)
        – Realistische Abschlusswahrscheinlichkeit:  
            • 1 = sehr unwahrscheinlich  
            • 10 = top-Potenzial  
        5. Liste in `missing_info` alle der sieben Felder auf, die im Input-JSON gar nicht zu finden waren.
        """
    resp = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": system_content},
            {"role": "user", "content":
                "PROJECT_JSON =\n" + json.dumps(full_proj, ensure_ascii=False, indent=2)
                + "\n\nCOMPANY_PROFILE =\n" + json.dumps(comp_profile, ensure_ascii=False, indent=2)
            }
        ],
        functions=functions,
        function_call={"name": "enrich_project"},
        temperature=0.2
    )
    func_call = resp.choices[0].message.function_call
    return json.loads(func_call.arguments)

TARGET_KEYS = ["title_de","customer","location","publicationDate","offerDeadline","contract_start","cpvCode","qna_deadline","projectId"]

def normalize(enriched: dict) -> dict:
    proj = enriched["project"]
    for k in TARGET_KEYS:
        proj.setdefault(k, None)
    return enriched

# --- 3. Batch-Loop über alle Projekte -------------------------------------
def enrich_projects_batch(projects: list[dict], comp_profile: dict) -> list[dict]:
    enriched_all = []
    for proj in projects:
        raw = enrich_project(proj, comp_profile)   # rohes GPT-Ergebnis
        normalized = normalize(raw)                 # hier füllen wir fehlende Keys auf
        enriched_all.append(normalized)
    return enriched_all

# --- 4. Hauptprogramm: Einlesen + Speichern -------------------------------
if __name__ == "__main__":
    # a) Lese deine Projekte ein (z.B. aus Datei, DB, API)
    projects = fetched_project_details_list
    enriched_list = enrich_projects_batch(projects, company_profile)
    high_score = [p for p in enriched_list if p.get("apply_score", 0) >= 8]


    with open("enriched_projects.json", "w", encoding="utf-8") as f_out:
        json.dump(high_score, f_out, ensure_ascii=False, indent=2)

    print(f"{len(high_score)} Projekte angereichert und in 'enriched_projects.json' gespeichert.")
# Out:
# 2 Projekte angereichert und in 'enriched_projects.json' gespeichert.

# %%
from datetime import datetime
def fmt_date(iso_str: str, fmt: str = "%d.%m.%Y") -> str:
    """
    Wandelt einen ISO-Datetime-String in das gewünschte Format um.
    Falls parsing fehlschlägt, wird der Original-String zurückgegeben.
    """
    try:
        # einige Deadlines kommen mit Zeit + Offset
        dt = datetime.fromisoformat(iso_str)
        return dt.strftime(fmt)
    except Exception:
        return iso_str


# -----------------------------
# 2. Slack-Block-Generator
# -----------------------------
def format_slack_blocks(proj: dict) -> list[dict]:
    team        = proj["team"]
    title       = proj["project"].get("title_de", "—")
    customer    = proj["project"].get("customer", "—")
    score       = proj.get("apply_score", 0)
    summary     = proj.get("summary", "—")
    project_number    = proj["project"].get("projectNumber", "—")
    projectId    = proj["project"].get("projectId", "—")
    offer_dl_raw    = proj["project"].get("offerDeadline", "—")
    start_raw       = proj["project"].get("contract_start", "—")
    qa_dl_raw       = proj["project"].get("qna_deadline", "—")
    cpv         = proj["project"].get("cpvCode", {})
    cpv_code    = cpv.get("code", "—")
    cpv_label   = cpv.get("label_de", "—")
    missing     = proj.get("missing_info", [])
    missing_str = ", ".join(missing) if missing else "Keine"

    offer_dl = fmt_date(offer_dl_raw, "%d.%m.%Y")
    qa_dl      = fmt_date(qa_dl_raw,    "%d.%m.%Y")
    start    = fmt_date(start_raw,  "%d.%m.%Y")

    text = (
       
        "\n"
        f":rocket: *Team: {team}*  *#{project_number}*\n"
        f"\n"
        f":file_folder: *Projekt:* {title} / {customer}\n"
        f"\n"
        f":star: *Apply Score:* *{score}*\n"
        f"\n"
        f":page_facing_up: *Zusammenfassung:*\n>{summary}\n\n"
        f":calendar:   •   *Q&A:* {qa_dl}   •   *Frist:* {offer_dl}   •   *Start:* {start} \n"
        f"\n"
        f":pushpin: *CPV:* `{cpv_code}` – {cpv_label}\n"
        "\n"
    )

    return [
        {"type": "divider"},
        {"type": "section", "text": {"type": "mrkdwn", "text": text}},
        {
            "type": "context",
            "elements": [
                {
                    "type": "mrkdwn",
                    "text": f"<https://www.simap.ch/de/project-detail/{projectId}#ausschreibung|🔗 Vollständige Ausschreibung>"
                }]
        },
        {"type": "divider"}
    ]

def post_to_slack_blocks(blocks: list[dict]):
    payload = {"blocks": blocks}
    resp = requests.post(
        webhook_url,
        json=payload,
        headers={"Content-Type": "application/json"},
        timeout=10
    )
    resp.raise_for_status()


for proj in high_score:
    blocks = format_slack_blocks(proj)
    try:
        post_to_slack_blocks(blocks)
        print(f"✅ Gesendet: {proj['project'].get('title_de')}")
    except Exception as e:
        print(f"❌ Fehler beim Senden von {proj['project'].get('title_de')}: {e}")
# Out:
# ✅ Gesendet: Datenaustauschplattform DAP
# ✅ Gesendet: 3870 NUCLEO - Omnichannel-Lösung für das CVC
